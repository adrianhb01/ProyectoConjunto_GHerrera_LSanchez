# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Gustavo Adrián Herrera Barragán & Luis Eduardo Sánchez Soto.
#
# **Fecha:** 11 de marzo del 2022.
#
# **Expediente** : 734546 & 734350 ######.
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link Github**: https://github.com/adrianhb01/ProyectoConjunto_GHerrera_LSanchez.git

# %% [markdown]
# –––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––

# %% [markdown]
# # Tarea 4: Clase: 9

# %% [markdown]
# >### <font color ='red'> **Tarea 4**
#
# > Para las siguiente dos funciones, genere muestres aleatorias que distribuyan según la función dada usando el método de la transformada inversa y grafique el histograma de 1000 muestras generadas con el método de la transformada inversa y compárela con el función $f(x)$ **(recuerde que $f(x)$ es la distribución de probabilidad y $F(x)$ es la distribución de probabilidad acumulada)** [ver este enlace para más información](https://es.wikipedia.org/wiki/Funci%C3%B3n_de_distribuci%C3%B3n). Este procedimiento se realiza con el fín de validar que el procedimiento y los resultados son correctos.
#
# > 1. Generación variable aleatoria continua
# >El tiempo en el cual un movimiento browniano se mantiene sobre su punto máximo en el intervalo [0,1] tiene una distribución
# >$$F(x)=\frac{2}{\pi}\sin^{-1}(\sqrt x),\quad 0\leq x\leq 1$$ </font>
#
# > 2. Generación variable aleatoria Discreta
# > La distribución binomial modela el número de éxitos de n ensayos independientes donde hay una probabilidad p de éxito en cada ensayo.
# > Generar una variable aletoria binomial con parámetros $n=10$ y $p=0.7$. Recordar que $$X\sim binomial(n,p) \longrightarrow p_i=P(X=i)=\frac{n!}{i!(n-i)!}p^i(1-p)^{n-i},\quad i=0,1,\cdots,n$$
# > Por propiedades de la operación factorial la anterior $p_i$ se puede escribir como:
# > $$p_{i+1}=\frac{n-i}{i+1}\frac{p}{1-p} p_i $$
#
# > **Nota:** Por notación recuerde que para el caso continuo $f(x)$ es la distribución de probabilidad (PDF), mientras $F(x)$ corresponde a la distribución de probabilidad acumulada (CDF). Para el caso discreto, $P(X=i)$ corresponde a su distribución de probabilidad (PMF) y $ F_{X}(x)=\operatorname {P} (X\leq x)=\sum _{x_{i}\leq x}\operatorname {P} (X=x_{i})=\sum _{x_{i}\leq x}p(x_{i})$, corresponde a su distribución de probabilidad acumulada (CDF).

# %% [markdown]
# –––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from scipy import optimize

# %% [markdown]
# ### Ejercicio 1:
# >Generación variable aleatoria continua
# >El tiempo en el cual un movimiento browniano se mantiene sobre su punto máximo en el intervalo [0,1] tiene una distribución
# >$$F(x)=\frac{2}{\pi}\sin^{-1}(\sqrt x),\quad 0\leq x\leq 1$$ </font>

# %% [markdown]
# #### Código de solución estudiante 1

# %%
#Código

# %% [markdown]
# #### Código de solución estudiante 2

# %%
#Código

#creamos una funcion lambda que retorna la inversa de F(x) variando un punto uniformemente distribuido
browniano = lambda x: (np.sin((np.pi/2)*x))**2 
# creamos 10000 valores aleatorios de una distribucion normal con numpy.random.rand()
dist = np.random.rand(100000)

fig, ax1 = plt.subplots(figsize=(12,6))

sns.histplot(browniano(dist), ax=ax1, color='blue', label='Histograma de frecuencias')
ax1.set_xlabel('Valores aleatorios')
ax1.set_ylabel('Frecuencia', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_title('Histograma y distribución de probabilidad con 100,000 generaciones')

x = np.linspace(0.01,0.99,200)
y = lambda x: 1/(np.pi*(np.sqrt(x*(1-x))))
ax2 = ax1.twinx()
sns.lineplot(x,y(x), ax=ax2, color='red', label='Distribución')
ax2.set_ylabel('Densidad de probabilidad', color='red')
ax2.tick_params(axis='y', labelcolor='red')

sns.set_style('whitegrid')
sns.set_palette('colorblind')

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.show()
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Igualamos la funcion de distribución a una distribucion **Uniforme** debido al intervalo que delimita  $F(x)$
# $$\frac{2}{\pi}\sin^{-1}(\sqrt x)=U$$
# $$\sin^{-1}(\sqrt x)=\frac{U\pi}{2}$$
# $$\sqrt x=\sin(\frac{U\pi}{2})$$
# $$\sqrt x=\sin(\frac{U\pi}{2})$$
#
# La funcion inversa es igual a
# $$x=\sin^{2}(\frac{U\pi}{2})$$
# En el intervalo
# $$\quad 0\leq U\leq 1$$

# %% [markdown]
# –––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––

# %% [markdown]
# ### Ejercicio 2:
# > Generación variable aleatoria Discreta
# > La distribución binomial modela el número de éxitos de n ensayos independientes donde hay una probabilidad p de éxito en cada ensayo.
# > Generar una variable aletoria binomial con parámetros $n=10$ y $p=0.7$. Recordar que $$X\sim binomial(n,p) \longrightarrow p_i=P(X=i)=\frac{n!}{i!(n-i)!}p^i(1-p)^{n-i},\quad i=0,1,\cdots,n$$
# > Por propiedades de la operación factorial la anterior $p_i$ se puede escribir como:
# > $$p_{i+1}=\frac{n-i}{i+1}\frac{p}{1-p} p_i $$

# %% [markdown]
# #### Código de solución estudiante 1

# %%
#Código

# %% [markdown]
# #### Código de solución estudiante 2

# %%
#Código

# %%
def binomial:'Valor n de binomial',p:'Probabilidad'):
    Pr = np.zeros(n)
    Pr[0] = (1-p)**n
    def pr(i):
        nonlocal Pr
        Pr[i+1]=((p/(1-p))*(n-i)/(i+1))*Pr[i]
    [pr(i) for i in range(n-1)]
    return np.cumsum(Pr)

def inversa(p_acum: 'Probabilidad acumulada',N: 'Cantidad de números a generar'):
    index = range(0,n+1)
    U =np.random.rand(N)
    # Diccionario de valores aleatorios
    rand2reales = {i: idx for i, idx in enumerate(index)}

    # Series de los valores aletorios
    y = pd.Series([sum([1 for p in p_acum if p < ui]) for ui in U]).map(rand2reales)
    return y
# Out:
#   File "<ipython-input-14-f3847a56b2cf>", line 1
#     def binomial:'Valor n de binomial',p:'Probabilidad'):
#                 ^
# SyntaxError: invalid syntax

# %%
def inversa(n: 'Variable n binomial',p:'Variable p binomial',N:'Simulaciones'):
    
    def acumulada():
        pi = np.zeros(n)
        pi[0] = (1-p)**n
        def p(i):
            nonlocal pi
            pi[i+1] = ((p/(1-p)) * (n-i) / (i+1)) * pi[i]
        [p(i) for i in range(n-1)]
        return pi.cumsum()
    pa = acumulada()
    U = np.random.rand(N)
    inv = np.array(list(map(lambda j:sum(1 for i in pa if i<U[j]),range(N))))
    return inv

# %%
n = 10
p = 0.7
N = 1000
sns.set(rc={'figure.figsize':(8,6)})
sns.histplot(np.random.binomial(n,p,N), binwidth=0.6, kde=True).set(title= "Distribucion Binomial")
# Out:
# [Text(0.5, 1.0, 'Distribucion Binomial')]

# %%
def inversa(n: 'Variable n binomial',vp:'Variable p binomial',N:'Simulaciones'):

    def acumulada():
        x = np.zeros(n)
        x[0] = (1-vp)**n
        def p(i):
            nonlocal x
            x[i+1]=((vp/(1-vp))*(n-i)/(i+1))*x[i]
        [p(i) for i in range(n-1)]
        return x.cumsum()
    pa = acumulada()
    U = np.random.rand(N)
    inv = np.array(list(map(lambda y:sum(1 for i in pa if U[y]>i),range(N))))
    return inv

# %%
sns.histplot(inversa(n,p,N), binwidth=0.6, kde=True, color="k").set(title= "Distribucion con tranformada Inversa");

# %% [markdown]
# –––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––

# %% [markdown]
# # Tarea 4: Clase 10

# %% [markdown]
# ### Ejemplo binomial:
# La distribución binomial modela el número de éxitos de n ensayos independientes donde hay una probabilidad p de éxito en cada ensayo.
#
# Generar una variable aletoria binomial con parámetros $n=10$ y $p=0.7$. Recordar que
# $$X\sim binomial(n,p) \longrightarrow p_i=P(X=i)=\frac{n!}{i!(n-i)!}p^i(1-p)^{n-i},\quad i=0,1,\cdots,n$$
# > ## <font color ='red'>Tarea: Demostrar la validez de la siguiente ecuación
# >$$p_{i+1}=\frac{n-i}{i+1}\frac{p}{1-p} p_i \longrightarrow \text{Hablar de las ventajas que sea recursiva}$$

# %% [markdown]
# #### Código de solución estudiante 1

# %%
#Código

# %% [markdown]
# #### Código de solución estudiante 2

# %%
#Código

# %% [markdown]
# –––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––

# %% [markdown]
# > ## <font color ='red'>Tarea
# Seguir un procedimiento similar al mostrado cuando se generó una distribución binomial, pero en esta caso genere un código que genere variables aletorias Poisson cuya función de distribución de probabilidad esta dada por:
# >$$P(k,\lambda)=\frac{e^{-\lambda}(\lambda)^k}{k!}$$
#
# > Demuestre matemáticamente que
# > $$P(k+1)=\frac{\lambda}{k+1}P(k)$$
# > y a partir de esta relación genere variables aletorias que distribuyen poisson usando el método de la transformada inversa.
#
# Enlace: https://es.wikipedia.org/wiki/Distribuci%C3%B3n_de_Poisson

# %% [markdown]
# $
# \begin{aligned}
# \frac{p_{k+1}}{p_k}& = \frac{e^{-\lambda}(\lambda)^k}{k!} \\
# & = \frac{e^{-\lambda}(\lambda)^k}{k!}
# \end{aligned}
# $

# %% [markdown]
# #### Código de solución estudiante 1

# %%
#Código

# %% [markdown]
# #### Código de solución estudiante 2

# %%
#Código

# %%
fx = lambda x: (x**2-2*x**3+x**4)*30
tx = lambda x: 2*np.sin(np.pi*x)
dominio = np.linspace(0,1,100)

# %%
plt.plot(dominio, fx(dominio), label='fx')
plt.plot(dominio, tx(dominio), label='tx')

plt.xlabel('Dominio')
plt.ylabel('Resultado')
plt.title('Comparacion de las funciones de distribucion fx y tx')
plt.legend()
plt.show()

# %% [markdown]
# –––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––

# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#808080; background:#fff;">
# Creado con Jupyter por: Gustavo Adrián Herrera Barragán & Luis Eduardo Sánchez Soto.
# </footer>
